# %%
import os
from dotenv import load_dotenv
# import requests
# import json
import pandas as pd
import applemusicpy
from iTunesKey import APP_KEY

load_dotenv()
team_id = os.getenv('TEAM_ID')
key_id = os.getenv('KEY_ID')
secret_key = APP_KEY
# secret_key = """{0}""".format(APP_KEY)
# CLIENT_SECRET = os.getenv('CLIENT_SECRET')


am = applemusicpy.AppleMusic(secret_key=secret_key, key_id=key_id, team_id=team_id)
# results = am.search('travis scott', types=['albums'], limit=5)
# for item in results['results']['albums']['data']:
#     print(item['attributes']['name'])

# {'id': '18',
#    'type': 'genres',
#    'href': '/v1/catalog/us/genres/18',
#    'attributes': {'parentName': 'Music',
#     'name': 'Hip-Hop/Rap',
#     'parentId': '34'}}
# results = am.genre(genre_id=34,storefront='us')


# Lupe IDs
# artistID 2851441
# albumID 1188857868

# results = am.artist(artist_id=898094630,storefront='us')

# results = am.album(album_id=1470132470,storefront='us')

results = am.search('Lecrae', storefront='us', types={'songs'})

# results = am.song(song_id=1652998965, storefront='us')

results


# sourceURL = "https://js-cdn.music.apple.com/musickit/v1/musickit.js"


# Reference:
# https://itunes.apple.com/search?term=lupe+fiasco
# https://itunes.apple.com/search?term=NF
# https://itunes.apple.com/search?term=lupe+fiasco&country=US&entity=music&limit=10
# https://itunes.apple.com/lookup?id=269747543&country=US&entity=song
# Out:
# Python-dotenv could not parse statement starting at line 3
# Python-dotenv could not parse statement starting at line 8
# {'results': {'songs': {'href': '/v1/catalog/us/search?limit=5&term=Lecrae&types=songs',
#    'next': '/v1/catalog/us/search?offset=5&term=Lecrae&types=songs',
#    'data': [{'id': '1273304909',
#      'type': 'songs',
#      'href': '/v1/catalog/us/songs/1273304909',
#      'attributes': {'albumName': 'All Things Work Together',
#       'genreNames': ['Hip-Hop/Rap', 'Music'],
#       'trackNumber': 11,
#       'durationInMillis': 217494,
#       'releaseDate': '2017-06-09',
#       'isrc': 'USSM11704779',
#       'artwork': {'width': 1500,
#        'height': 1500,
#        'url': 'https://is4-ssl.mzstatic.com/image/thumb/Music125/v4/1d/ca/55/1dca55da-0946-447b-aeb6-3b31999d66b1/886446671888.jpg/{w}x{h}bb.jpg',
#        'bgColor': '0c1011',
#        'textColor1': 'edefe2',
#        'textColor2': 'cfccce',
#        'textColor3': 'c0c3b8',
# ...
